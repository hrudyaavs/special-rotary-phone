# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Wine_clust  (1).csv')
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
clusters_range = range(2, 11)

# %%
kmeans_scores = []
hierarchical_scores = []
dbscan_scores = []

# %% [markdown]
# KMEAN CLUSTERING

# %%
for n_clusters in clusters_range:
    kmeans = KMeans(n_clusters=10, random_state=42)
    kmeans_labels = kmeans.fit_predict(data)
    silhouette_avg = silhouette_score(data, kmeans_labels)
    kmeans_scores.append(silhouette_avg)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# HIERARCHICAL CLUSTERING

# %%
for n_clusters in clusters_range:
    hierarchical = AgglomerativeClustering(n_clusters=n_clusters)
    hierarchical_labels = hierarchical.fit_predict(data)
    silhouette_avg = silhouette_score(data, hierarchical_labels)
    hierarchical_scores.append(silhouette_avg)

# %% [markdown]
# DB SCAN CLUSTERING

# %%
dbscan = DBSCAN(eps=0.6, min_samples=5)
dbscan_labels = dbscan.fit_predict(data)
le = sklearn.preprocessing.LabelEncoder()
le.fit(dbscan_labels)
dbscan_labels = dbscan_labels.astype(int)
dbscan_silhouette_avg = silhouette_score(data[data['Alcohol'] > 10], dbscan_labels)
dbscan_scores = [dbscan_silhouette_avg] * len(clusters_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-fd02eee4c6ac> in <cell line: 6>()
#       4 le.fit(dbscan_labels)
#       5 dbscan_labels = dbscan_labels.astype(int)
# ----> 6 dbscan_silhouette_avg = silhouette_score(data[data['Alcohol'] > 10], dbscan_labels)
#       7 dbscan_scores = [dbscan_silhouette_avg] * len(clusters_range)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     229     n_samples = len(labels)
# ...
